# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Thany Lailat/Desktop/sales_predictions.csv')
print('data loaded')
# Out:
# data loaded

# %%
df.head()
# Out:
#   date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  NaT               0       59    22154      999.00           1.0
# 1  NaT               0       25     2552      899.00           1.0
# 2  NaT               0       25     2552      899.00          -1.0
# 3  NaT               0       25     2554     1709.05           1.0
# 4  NaT               0       25     2555     1099.00           1.0

# %%
#En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution
#des prix par rapport au temps. Que pouvez vous voir ?
sns.relplot(x='date', y='item_price', data=df)

# %%
#Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas,
#prenez un échantillons de 50 éléments dans votre dataset
sns.relplot(x='date', y='item_price', data=df.sample(n=50))

# %%
#Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?
sns.relplot(x='date', y='item_price', data=df.sample(n=50), height=10)

# %%
#En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime
df.date = pd.to_datetime(df.date).sample(n=50)

# %%
#6) Retentez une dernière fois votre visualisation.
sns.relplot(x='date', y='item_price', data=df, height=10)
